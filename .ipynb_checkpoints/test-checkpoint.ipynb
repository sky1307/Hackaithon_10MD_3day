# %%
import sys
from tensorflow import keras
import yaml
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from ensemble import Ensemble
import tensorflow.keras.backend as K
# Out:
# 2022-01-28 22:41:17.230148: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-28 22:41:17.230167: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
with open("./settings/model/config.yaml", 'r') as stream:
        config =yaml.load(stream ,Loader=  yaml.FullLoader)

# %%
# log_dir= config['log_dir']
data_file = './data/SonTay.csv'
df = pd.read_csv (data_file).iloc[:120]

# %%
df.shape
# Out:
# (120, 6)

# %%
def plot_qh(df):
    plt.subplots(1, figsize=(13, 7))
    plt.plot(df['Q'],marker=',', linewidth='0.8', label='Q')
    plt.xlabel('minute')
   
    
    # plt.plot(df['Q_ssa'],marker=',', linewidth='0.8', label='Q_ssa')
    # plt.xlabel('minute')
    
    plt.plot(df['H'],marker=',', linewidth='0.8', label='H')
    plt.xlabel('minute')
   
    
    # plt.plot(df['H_ssa'],marker=',', linewidth='0.8', label='H_ssa')
    # plt.xlabel('minute')
    
    
    
    plt.ylabel('BTCUSDT')
    plt.title('High - Low')
    plt.legend()
    plt.show()

# %%
plot_qh(df)

# %%
def extract_window_data(df, window_len=30):
    window_data = []
    for idx in range(len(df) - window_len):
        tmp = df[idx: (idx + window_len)].copy()
        window_data.append(tmp.values)
    return np.array(window_data)

def prepare_data(df, window_len=30):
    data_x = extract_window_data(df, window_len)
    data_y = df[window_len:].values
    return data_x, data_y

# %%
data_x, data_y = prepare_data(df, window_len=30)
data_y.shape
# data_y.shape
# Out:
# (90, 6)

# %%
len(df)
# Out:
# 120

# %%
K.clear_session()
sigma_index_lst = [0,1]
epoch_num = 8
model = Ensemble(mode='test', model_kind='rnn_cnn', sigma_lst=sigma_index_lst,
                     default_n=20, epoch_num=epoch_num, epoch_min=100, epoch_step=50, **config)
model.train_model_outer()
# Out:
# train_in x:  (2970, 30, 2) y:  (2970, 2)
# test_in x:  (1949, 30, 2) y:  (1949, 2)
# test_out x:  (50, 30, 2) y:  (50, 2)
# 2022-01-28 22:43:21.282655: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-01-28 22:43:21.282696: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-01-28 22:43:21.282715: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (sky-ubuntu): /proc/driver/nvidia/version does not exist
# 2022-01-28 22:43:21.282864: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (1949, 1, 16)
# Input shape: (1949, 1, 16)
# Load weight from ./log/model/

# %%
x_ = data_x[0][:,:2]

# %%
y_pred = []

for x in data_x:
    x_ = x[:,:2][np.newaxis, :]
    y_ = model.prediction_vp(x_

# %%
x_[:,:,0] = (x_[:,:,0] -minn[0])/(maxx[0]-minn[0])
x_[:,:,1] = (x_[:,:,1] -minn[1])/(maxx[1]-minn[1])

# %%
36217.89240270115 35574.05575267486
36578.92947186589 35029.51459553689

35906.3,35868.09
35728.89537888335 36060.66047321461
# Out:
# array([[[17817.605, 35581.79 ],
#         [17828.655, 35605.81 ],
#         [17835.605, 35639.61 ],
#         [17853.24 , 35671.21 ],
#         [17852.865, 35670.96 ],
#         [17875.79 , 35696.48 ],
#         [17897.975, 35697.99 ],
#         [17894.335, 35688.71 ],
#         [17902.63 , 35754.09 ],
#         [17936.415, 35751.59 ],
#         [17933.975, 35812.99 ],
#         [17910.04 , 35778.42 ],
#         [17906.23 , 35769.11 ],
#         [17909.535, 35789.9  ],
#         [17909.05 , 35795.01 ],
#         [17938.295, 35813.66 ],
#         [17938.295, 35815.33 ],
#         [17930.29 , 35824.51 ],
#         [17946.   , 35855.37 ],
#         [17964.5  , 35874.06 ],
#         [17957.75 , 35861.14 ],
#         [17945.175, 35822.81 ],
#         [17947.5  , 35830.03 ],
#         [17948.935, 35843.82 ],
#         [17935.5  , 35815.02 ],
#         [17911.   , 35795.95 ],
#         [17909.79 , 35797.22 ],
#         [17924.845, 35801.67 ],
#         [17932.505, 35831.79 ],
#         [17950.65 , 35863.09 ]]])

# %%
K.clear_session()
sigma_index_lst = [0,1]
epoch_num = 8
model = Ensemble(mode='test', model_kind='rnn_cnn', sigma_lst=sigma_index_lst,
                     default_n=20, epoch_num=epoch_num, epoch_min=100, epoch_step=50, **config)
model.train_model_outer()
model
